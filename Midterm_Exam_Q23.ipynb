# %% [markdown]
# <a href="https://colab.research.google.com/github/Cabangoncpe/CPE-009A-CPE12S2/blob/main/Midterm_Exam_Q23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Midterm Exam Question 23

a = "*"
b = 1
c = 3
while b < 6:
 print(b * a)
 b += 1
while c > 0:
 print(c * a)
 c -= 1
# Out:
# *
# **
# ***
# ****
# *****
# ***
# **
# *
