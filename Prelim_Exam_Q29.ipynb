# %% [markdown]
# <a href="https://colab.research.google.com/github/Cabangoncpe/CPE-009A-CPE12S2/blob/main/Prelim_Exam_Q29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Cabangon, Mike Justin A.

# %%
EXAM = int
HOAM = int
QUIM = int
GRAM = int
EXAE = int
HOAE = int
QUIE = int
GRAE = int
input("Enter student name: ")
input("Enter student ID: ")
print ("---Calculation For Math Course---") #marks for Math course
EXAM = int(input("Enter student EXAM marks(%): "))
HOAM = int(input("Enter student HOA marks(%): "))
QUIM = int(input("Enter student QUIZ marks(%): "))
GRAM = ((EXAM + HOAM + QUIM) / 3)
print ("Math course grade: "), print (GRAM)

if GRAM >= 90:
    print ("Letter Grade: A+")
    print ("Remarks: Outstanding")
elif GRAM >= 80:
    print ("Letter Grade: A")
    print ("Remarks: Excellent")
elif GRAM >= 70:
    print ("Letter Grade: B+")
    print ("Remarks: Very Good")
elif GRAM >= 60:
    print ("Letter Grade: B")
    print ("Remarks: Good")
elif GRAM >= 50:
    print ("Letter Grade: C")
    print ("Remarks: Satisfactory")
elif GRAM >= 40:
    print ("Letter Grade: D")
    print ("Remarks: Satisfactory")
elif GRAM < 40:
    print ("Letter Grade: F (Fail)")
    print ("Remarks: Needs Improvement")

print ("---Calculation For English Course---") #marks for English course
EXAE = int(input("Enter student EXAM marks(%): "))
HOAE = int(input("Enter student HOA marks(%): "))
QUIE = int(input("Enter student QUIZ marks(%): "))
GRAE = ((EXAE + HOAE + QUIE) / 3)
print ("Math course grade: "), print (GRAE)

if GRAE >= 90:
    print ("Letter Grade: A+")
    print ("Remarks: Outstanding")
elif GRAE >= 80:
    print ("Letter Grade: A")
    print ("Remarks: Excellent")
elif GRAE >= 70:
    print ("Letter Grade: B+")
    print ("Remarks: Very Good")
elif GRAE >= 60:
    print ("Letter Grade: B")
    print ("Remarks: Good")
elif GRAE >= 50:
    print ("Letter Grade: C")
    print ("Remarks: Satisfactory")
elif GRAE >= 40:
    print ("Letter Grade: D")
    print ("Remarks: Satisfactory")
elif GRAE < 40:
    print ("Letter Grade: F (Fail)")
    print ("Remarks: Needs Improvement")
# Out:
# Enter student name: Callum Bulwark
# Enter student ID: 0091101
# ---Calculation For Math Course---
# Enter student EXAM marks(%): 100
# Enter student HOA marks(%): 45
# Enter student QUIZ marks(%): 56
# Math course grade:
# 67.0
# Letter Grade: B
# Remarks: Good
# ---Calculation For English Course---
# Enter student EXAM marks(%): 87
# Enter student HOA marks(%): 92
# Enter student QUIZ marks(%): 94
# Math course grade:
# 91.0
# Letter Grade: A+
# Remarks: Outstanding
