# %% [markdown]
# <a href="https://colab.research.google.com/github/Cabangoncpe/CPE-009A-CPE12S2/blob/main/Midterm_Exam_Q24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Midterm Exam Question 24

S = input("Enter a string: ")
a = "({[]})"
b = "((()))"
c = "([)]"
d = "({)}"

bool = a == S
print(bool)
bool = b == S
print(bool)
bool = c == S
print(bool)
bool = d == S
print(bool)
# Out:
# Enter a string: ((()))
# False
# True
# False
# False
