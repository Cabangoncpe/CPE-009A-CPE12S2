# %% [markdown]
# <a href="https://colab.research.google.com/github/Cabangoncpe/CPE-009A-CPE12S2/blob/main/2_26_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Built-in Date Types

# %%
pi = 3.14159
varList = [1, 2, 'A', 'B', 'Hello!', pi]
print(varList[0])
# Out:
# 1

# %%
print(varList[4])
# Out:
# Hello!

# %%
varList.append('World!')
print(varList[6])
# Out:
# World!

# %%
len(varList)
# Out:
# 7

# %%
print(varList[5])
# Out:
# 3.14159

# %%
varList.remove(pi)
print(varList[5])
# Out:
# World!
