# %% [markdown]
# <a href="https://colab.research.google.com/github/Cabangoncpe/CPE-009A-CPE12S2/blob/main/Laboratory_Activity_3_Sequence_and_Mapping_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Laboratory Activity 3 - Sequence and Mapping Types

# %% [markdown]
# Supplementary

# %%
#1
coords_list = [(1, 1), (2, 3)]
def calculate_distance(coords):
  (x1, y1), (x2, y2) = coords
  return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

distance = calculate_distance(coords_list)
print("Distance:", distance)
# Out:
# Distance: 2.23606797749979

# %%
#2
text = input("Enter a sentence: ")
print(text.replace("asterisk", "*"*len("asterisk")))
# Out:
# Enter a sentence: what are these asterisk?
# what are these ********?

# %%
#3
phonebook = {
    19: {"name": "Mike", "contact": "001-1234", "address": "123 Karunungan St"},
    21: {"name": "Val", "contact": "003-9876", "address": "789 Tulay Rd"},
    26: {"name": "Soph", "contact": "002-5678", "address": "456 Kaibigan St"}
}

user_id = int(input("Enter ID: "))
record = phonebook.get(user_id)

print(f"Name: {record['name']}\nContact: {record['contact']}\nAddress: {record['address']}" if record else "No record found.")
# Out:
# Enter ID: 21
# Name: Val
# Contact: 003-9876
# Address: 789 Tulay Rd
