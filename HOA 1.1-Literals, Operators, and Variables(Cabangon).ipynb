# %% [markdown]
# <a href="https://colab.research.google.com/github/Cabangoncpe/CPE-009A-CPE12S2/blob/main/HOA%201.1-Literals%2C%20Operators%2C%20and%20Variables(Cabangon).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hands-on Activity 1.1 Literals, Operators, and Variables

# %% [markdown]
# **Assigning variables of different data types in Python:**

# %%
#1.
value = 5
print(value)
# Out:
# 5

# %%
#2
t.pe(value)
# Out:
# int

# %%
#3.
value = 5.0
print(value)
# Out:
# 5.0

# %%
#4.
type(value)
# Out:
# set

# %%
#5.a
value = 2+3j
print(value)
# Out:
# (2+3j)

# %%
type(value)
# Out:
# complex

# %%
#5.b
value = 'Hello World'
print(value)
# Out:
# Hello World

# %%
type(value)
# Out:
# str

# %%
#5.c
value = "Hello World"
print(value)
# Out:
# Hello World

# %%
type(value)
# Out:
# str

# %%
#5.d
value = True
print(value)
# Out:
# True

# %%
type(value)
# Out:
# bool

# %%
#5.e
value = False
print(value)
# Out:
# False

# %%
type(value)
# Out:
# bool

# %%
#5.f
value = [1,2,3,4,5]
print(value)
# Out:
# [1, 2, 3, 4, 5]

# %%
type(value)
# Out:
# list

# %%
#5.g
value = (1,2,3,4,5)
print(value)
# Out:
# (1, 2, 3, 4, 5)

# %%
type(value)
# Out:
# tuple

# %%
#5.h
value = {'name:' 'Mike Justin Cabangon'}
print(value)
# Out:
# {'name:Mike Justin Cabangon'}

# %%
type(value)
# Out:
# set

# %%
#5.i
value = None
print(value)
# Out:
# None

# %%
type(value)
# Out:
# NoneType

# %%
#6
value = 5
#7
value2 = -6

# %% [markdown]
# **Performing Operations with Python**

# %%
#1.
print(value+value2)
# Out:
# -1

# %%
#2.a
value, value2 = 5.0, 6
print(value, value2)
# Out:
# 5.0 6

# %%
#2.b
value, value2 = -5, 6.1
print(value, value2)
# Out:
# -5 6.1

# %%
#2.c
value, value2 = "Hello", 'World'
print(value, value2)
# Out:
# Hello World

# %%
#2.d
value, value2 = [1,2,3], [4,5,6]
print(value, value2)
# Out:
# [1, 2, 3] [4, 5, 6]

# %%
#2.e
value, value2 = (1,2,3), (4,5,6)
print(value, value2)
# Out:
# (1, 2, 3) (4, 5, 6)

# %%
#2.f
value, value2 = {"name":"Mike"}, {"age":18}
print(value, value2)
# Out:
# {'name': 'Mike'} {'age': 18}

# %%
#3.
value, value2 = 30, 4
print(value, value2)
# Out:
# 30 4

# %%
#3.a
print(value*value2)
# Out:
# 120

# %%
#3.b
print(value2**2)
# Out:
# 16

# %%
#3.c
print(value2**3)
# Out:
# 64

# %%
#3.d
print(value*value2+value2**2+1)
# Out:
# 137

# %%
#3.e
print(value/value2)
# Out:
# 7.5

# %%
#3.f
print(value%value2)
# Out:
# 2

# %% [markdown]
# **Assigning Input Data to a Variable**

# %%
#1
name = input("Enter your name: ")
#2
weight = float(input("Enter your weight (kg): "))
#3
height = float(input("Enter your height (m): "))
#4
bmi = weight / (height ** 2)
print(f"BMI = {bmi:.4f}")
# Out:
# Enter your name: Mike Justi n Cabangon
# Enter your weight (kg): 56.5
# Enter your height (m): 1.77
# BMI = 18.0344

# %% [markdown]
# SUPPLEMENTARY ACTIVITY:

# %%
#1
base, height, area = 0, 0, 0
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))

area = 0.5 * base * height

print(f"The area of the triangle is: {area:.4f}")
# Out:
# Enter the base of the triangle: 4
# Enter the height of the triangle: 6
# The area of the triangle is: 12.0000

# %%
#2
C = 0
C = float(input("Enter Celsius to Convert to Fahrenheit: "))

Fahrenheit = C*(9.5)+32
print(f"The Fahrenheit is: {Fahrenheit}°F")
# Out:
# Enter Celsius to Convert to Fahrenheit: 0
# The Fahrenheit is: 32.0°F

# %%
#3
x1, y1, x2, y2 = 0, 0, 0, 0
x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))
x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))

distance = ((x2-x1)**2 + (y2-y1)**2)**0.5
print(f"The distance between the two points is: {distance:.3f}")
# Out:
# Enter x1: 4
# Enter y1: 8
# Enter x2: 1
# Enter y2: 12
# The distance between the two points is: 5.000
