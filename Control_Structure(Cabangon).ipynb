# %% [markdown]
# <a href="https://colab.research.google.com/github/Cabangoncpe/CPE-009A-CPE12S2/blob/main/Control_Structure(Cabangon).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# If Statement

# %%
a=12
b=100
if b>a:
  print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# Elif Statemet

# %%
a=12
b=12
if b>a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a and b are equal

# %% [markdown]
# Else Statement

# %%
a=12
b=11
if b>a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short Hand If Statement

# %%
a=12
b=11
if a>b: print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short Hand If.. Else Statement

# %%
a=12
b=330
print("a is greater than b") if a>b else print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# Or-at least one of the condition is true

# %%
a=200
b=33
c=500
if a>b or a>c:
  print("At least one of the condition is true")
# Out:
# At least one of the condition is true

# %% [markdown]
# Nested If and If.. Else

# %%
#+5 points
x=41

if x>10:
  print("Above ten,")
  if x>20:
    print("and also above 20")
    if x>30:
      print("and also above 30")
      if x>40:
        print("and also above 40")
        if x>50:
          print("and also above 50")
        else:
          print("but not above 50.")
    else:
      print("but not above 30.")
  else:
    print("below 20.")
else:
  print("below 10")
# Out:
# Above ten,
# and also above 20
# and also above 30
# and also above 40
# but not above 50.

# %% [markdown]
# Supplementary

# %%
#Supplementary: Example 1 - age (qualified to vote or not)

x = age = int(input("Enter age: "))

if x >= 18:
  print("Qualified to vote")
else:
  print("Not qualified to vote")
# Out:
# Enter age: 21
# Qualified to vote

# %%
#Supplementary: Example 3 - grade qualification
#+5 points
x = grade = float(input("Enter grade: "))

if x >= 75:
  print("Passed")
elif x == 74:
  print("Remedial")
else:
  print("Failed")
# Out:
# Enter grade: 67
# Failed
